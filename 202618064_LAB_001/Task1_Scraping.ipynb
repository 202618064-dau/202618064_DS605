# %% [markdown]
# Task 1 - Data Scraping using scrapy
#
# The goal of this task is to scrape information (title,
# category, price, rating, availability, product description, UPC, number of reviews, and product URL.) from Website: https://books.toscrape.com/ using the Scrapy framework.
#
# The spider extracts information from catalogue pages 20–25 and visits each individual product page to collect detailed information.
#
# The extracted attributes include:
#
# - Title
# - Category
# - Price
# - Rating
# - Availability
# - Description
# - UPC
# - Number of Reviews
# - Product URL

# %% [markdown]
# Checking the Current Working Directory

# %%
import os

print(os.getcwd())
# Out:
# d:\202618064_DS605\202618064_LAB_001

# %% [markdown]
# Listing Files and Folders

# %%
import os

os.listdir("bookscraper/bookscraper")
# Out:
# ['books_raw.csv',
#  'items.py',
#  'middlewares.py',
#  'pipelines.py',
#  'settings.py',
#  'spiders',
#  '__init__.py',
#  '__pycache__']

# %% [markdown]
# Loading the Scraped Dataset

# %%
books.head()
# Out:
#                                               Title            Category  \
# 0                                         The Widow             Mystery
# 1                                 A Paris Apartment  Historical Fiction
# 2                     Boar Island (Anna Pigeon #19)             Mystery
# 3  Can You Keep a Secret? (Fear Street Relaunch #4)              Horror
# 4                               Dirty (Dive Bar #1)             Romance
#
#     Price Rating Availability  \
# 0  £27.26    Two     In stock
# 1  £39.01   Four     In stock
# 2  £59.48  Three     In stock
# 3  £48.64    One     In stock
# 4  £40.83   Four     In stock
#
#                                          Description               UPC  \
# 0  THE NEW YORK TIMESBESTSELLERFor fans of Gone G...  6159d8b187831770
# 1  Bienvenue à Paris!When April Vogt's boss tells...  63343e287971bb0c
# 2  Bringing you a gripping mystery, Nevada Barr t...  49b24c6a41b82bd2
# ...

# %% [markdown]
# Total Number of Records

# %%
len(books)
# Out:
# 120

# %% [markdown]
# Dataset Information

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              120 non-null    object
#  1   Category           120 non-null    object
#  2   Price              120 non-null    object
#  3   Rating             120 non-null    object
#  4   Availability       120 non-null    object
#  5   Description        120 non-null    object
#  6   UPC                120 non-null    object
#  7   Number_of_Reviews  120 non-null    int64
#  8   Product_URL        120 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 8.6+ KB

# %% [markdown]
# Checking for NULL Values

# %%
books.isnull().sum()
# Out:
# Title                0
# Category             0
# Price                0
# Rating               0
# Availability         0
# Description          0
# UPC                  0
# Number_of_Reviews    0
# Product_URL          0
# dtype: int64

# %% [markdown]
# Checking for Duplicate UPC Values

# %%
books["UPC"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Conclusion
#
# Successfully scraped book information from pages 20–25 of the BooksToScrape website using Scrapy.
#
# The extracted data was stored in a CSV file and validated using Pandas.
#
# The dataset was inspected for size, structure, missing values, and duplicate UPC values.
